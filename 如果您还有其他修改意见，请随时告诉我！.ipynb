# %% [markdown]
# <a href="https://colab.research.google.com/github/smartlibo/-/blob/main/%E5%A6%82%E6%9E%9C%E6%82%A8%E8%BF%98%E6%9C%89%E5%85%B6%E4%BB%96%E4%BF%AE%E6%94%B9%E6%84%8F%E8%A7%81%EF%BC%8C%E8%AF%B7%E9%9A%8F%E6%97%B6%E5%91%8A%E8%AF%89%E6%88%91%EF%BC%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from weasyprint import HTML
import base64

# Define the data for the comparison
aircraft_data = [
    {
        "name": "An-124 Ruslan",
        "country": "俄罗斯",
        "weight": "402 t",
        "payload": "150 t",
        "length": "68.9 m",
        "wingspan": "73.3 m",
        "color": "#2c3e50",
        "scale": 1.0
    },
    {
        "name": "C-5M Super Galaxy",
        "country": "美国",
        "weight": "381 t",
        "payload": "129 t",
        "length": "75.3 m",
        "wingspan": "67.9 m",
        "color": "#2980b9",
        "scale": 0.92
    },
    {
        "name": "C-17 Globemaster III",
        "country": "美国",
        "weight": "265 t",
        "payload": "77 t",
        "length": "53.0 m",
        "wingspan": "51.8 m",
        "color": "#8e44ad",
        "scale": 0.75
    },
    {
        "name": "Y-20 (运-20)",
        "country": "中国",
        "weight": "220 t",
        "payload": "66 t",
        "length": "47.0 m",
        "wingspan": "45.0 m",
        "color": "#c0392b",
        "scale": 0.68
    }
]

html_content = f"""
<!DOCTYPE html>
<html lang="zh">
<head>
<meta charset="UTF-8">
<style>
    @page {{
        size: A4;
        margin: 0;
        background-color: #f4f7f6;
    }}
    body {{
        font-family: 'PingFang SC', 'Hiragino Sans GB', 'Microsoft YaHei', sans-serif;
        margin: 0;
        padding: 40px;
        color: #333;
    }}
    .header {{
        text-align: center;
        padding-bottom: 20px;
        border-bottom: 2px solid #ddd;
        margin-bottom: 30px;
    }}
    .header h1 {{
        margin: 0;
        font-size: 24pt;
        color: #2c3e50;
    }}
    .header p {{
        font-size: 12pt;
        color: #7f8c8d;
    }}

    .infographic-container {{
        position: relative;
        height: 400px;
        margin-bottom: 40px;
        background: white;
        border-radius: 8px;
        padding: 20px;
        box-shadow: 0 4px 6px rgba(0,0,0,0.05);
    }}

    .aircraft-visual {{
        display: block;
        margin: 0 auto;
        position: relative;
        width: 100%;
        height: 100%;
    }}

    .comparison-bar {{
        display: flex;
        align-items: flex-end;
        justify-content: space-around;
        height: 300px;
        padding-top: 50px;
    }}

    .bar-item {{
        text-align: center;
        width: 20%;
    }}

    .shape {{
        margin: 0 auto;
        border-radius: 4px 4px 0 0;
        transition: height 0.3s;
    }}

    .label {{
        margin-top: 10px;
        font-weight: bold;
        font-size: 10pt;
    }}

    .table-container {{
        width: 100%;
        border-collapse: collapse;
        margin-top: 20px;
        background: white;
        border-radius: 8px;
        overflow: hidden;
        box-shadow: 0 4px 6px rgba(0,0,0,0.05);
    }}

    th {{
        background-color: #2c3e50;
        color: white;
        text-align: left;
        padding: 12px;
        font-size: 11pt;
    }}

    td {{
        padding: 12px;
        border-bottom: 1px solid #eee;
        font-size: 10pt;
    }}

    tr:last-child td {{
        border-bottom: none;
    }}

    .stat-badge {{
        display: inline-block;
        padding: 2px 8px;
        border-radius: 10px;
        font-size: 9pt;
        color: white;
        font-weight: bold;
    }}

</style>
</head>
<body>
    <div class="header">
        <h1>全球顶级战略运输机数据对比</h1>
        <p>An-124 vs C-5M vs C-17 vs Y-20</p>
    </div>

    <div class="infographic-container">
        <div style="text-align: center; font-size: 10pt; color: #95a5a6; margin-bottom: 20px;">
            — 最大载重能力直观对比 (单位: 吨) —
        </div>
        <div class="comparison-bar">
            {"".join([f'''
            <div class="bar-item">
                <div style="font-size: 11pt; font-weight: bold; color: {a['color']}; margin-bottom: 5px;">{a['payload']}</div>
                <div class="shape" style="height: {int(a['scale']*250)}px; width: 60px; background-color: {a['color']};"></div>
                <div class="label" style="color: {a['color']};">{a['name'].split()[0]}</div>
            </div>
            ''' for a in aircraft_data])}
        </div>
    </div>

    <table class="table-container">
        <thead>
            <tr>
                <th>机型名称</th>
                <th>国家/地区</th>
                <th>最大起飞重量</th>
                <th>最大载重量</th>
                <th>机身长度</th>
                <th>翼展</th>
            </tr>
        </thead>
        <tbody>
            {"".join([f'''
            <tr>
                <td style="font-weight: bold;">{a['name']}</td>
                <td>{a['country']}</td>
                <td>{a['weight']}</td>
                <td><span class="stat-badge" style="background-color: {a['color']};">{a['payload']}</span></td>
                <td>{a['length']}</td>
                <td>{a['wingspan']}</td>
            </tr>
            ''' for a in aircraft_data])}
        </tbody>
    </table>

    <div style="margin-top: 30px; padding: 15px; background: #eef2f3; border-left: 5px solid #2c3e50; font-size: 10pt; line-height: 1.6;">
        <strong>技术笔记：</strong><br>
        1. <strong>An-124</strong> 是目前世界上服役中最大的量产军用运输机。<br>
        2. <strong>C-5M</strong> 是美军战略投送的基石，长度超过 An-124，但最大载重略逊一筹。<br>
        3. <strong>Y-20 (运-20)</strong> 的数据基于目前公开的 200 吨级平台估算，换装 WS-20 发动机后其性能正处于持续提升阶段。
    </div>
</body>
</html>
"""

output_path = "Aircraft_Comparison_Infographic.pdf"
HTML(string=html_content).write_pdf(output_path)

# %%
import os
from google.colab import files

filename = 'Aircraft_Comparison_Infographic.pdf'
if os.path.exists(filename):
    files.download(filename)
else:
    print(f"Error: File '{filename}' not found. Please ensure the PDF generation cell (OJ9kWLgr5Iim) has been executed.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2743/3703919709.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download('Aircraft_Comparison_Infographic.pdf')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: Aircraft_Comparison_Infographic.pdf

# %% [markdown]
# 您的全球顶级战略运输机对比文档已准备就绪。
#
# 在此次对比中，我已按照您的要求将已退役/毁损的 An-225 替换为目前全球在役最大的量产运输机 **An-124 (安-124)**。
#
# ### 排名与关键发现：
#
# 1. **An-124 "Ruslan"**：稳居现役榜首，最大载重达到惊人的 150 吨，是真正的空中巨无霸。
# 2. **C-5M "Super Galaxy"**：紧随其后，虽然机身长度（75.3m）超过了 An-124，但最大载重能力约为 129 吨，排名第二。
# 3. **C-17 "Globemaster III"**：作为战略/战术混合运输机的标杆，载重约 77 吨，位列第三。
# 4. **运-20 (Y-20)**：作为中国空军的战略核心，目前处于 200 吨级第一梯队，载重约 66 吨。随着换装更强大的国产发动机，其潜力仍在不断释放。
#
# 在生成的 PDF 报告中，您可以看到直观的载重对比柱状图以及详尽的技术参数表格，方便您进行更深入的比较。
